# %% [markdown]
# <a href="https://colab.research.google.com/github/aimanshahid800/Quater_3_/blob/main/image_prompting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
import google.generativeai as genai

# Get the API key from userdata
API_KEY = userdata.get("GOOGLE_API_KEY")

# Configure the genai client
genai.configure(api_key=API_KEY)

# %%
model = genai.GenerativeModel("gemini-1.5-flash")

# %%
import requests
from PIL import Image
from io import BytesIO
from IPython.display import display

# Replace with the URL of your image
url = 'https://i.pinimg.com/550x/36/7c/b9/367cb97b53ba422436fc2cb47cdd2ccf.jpg'

# Fetch the image from the URL
response = requests.get(url)

# Open the image using PIL
img = Image.open(BytesIO(response.content))

# Display the image inline in Jupyter Notebook
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=549x543>

# %%
prompt = """elaborate the image  detail"""

# %%
response = model.generate_content([prompt, img])
print(response.text)
# Out:
# Here's a description of the image:
#
# The image is a stylized anime-style illustration or edit of a young girl.
#
#
# Here's a breakdown of the details:
#
# * **Character:** The girl has long, dark brown or black hair that frames her face. Her eyes are closed, and she has a soft, gentle expression.  Her cheeks are adorned with a blush effect, depicted as small, light pink stars. She appears to be sleeping or resting peacefully.  The style is reminiscent of soft girl or kawaii aesthetics.
#
# * **Clothing:** She's wearing a light-colored, possibly off-white or cream-colored, sweater or hoodie. The fabric looks soft and textured.
#
# * **Background:** The background is blurred and dark, suggesting an indoor setting. Part of what appears to be a brown or reddish-brown piece of furniture is visible.
#
# ...
